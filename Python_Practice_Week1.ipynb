# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasmalhotra9/FirstGitProject/blob/main/Python_Practice_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Store your name in a variable and print it.

# %%
Name = ("Vikas Malhotra is going to beome genius" , "He will create history")
print(Name)
# Out:
# ('Vikas Malhotra is going to beome genius', 'He will create history')

# %% [markdown]
# 2. Store your age in a variable and then print your age

# %%
Age = 39
print("Vikas age is" , Age)
# Out:
# Vikas age is 39

# %% [markdown]
# 3. Create variables for city and country.

# %%
city = "Yamunanagar"
country = "India"
print("My city is" , city)
print("My country is" ,country)
# Out:
# My city is Yamunanagar
# My country is India

# %% [markdown]
# 4. Store two numbers and print their sum.

# %%
a = 5
b = 9

print("Sum of two numbers is" , a+b)
# Out:
# Sum of two numbers is 14

# %% [markdown]
# 5. Swap two variables. (Swapping two times with two different methods)

# %%
a = 7
b = 9

a,b = b,a

x = b
b = a
a = x

print("Value of a is" , a)
print("Value of b is" , b)
# Out:
# Value of a is 7
# Value of b is 9

# %% [markdown]
# 6. Store a mobile number in a variable.

# %%
Mobile_Number = 919639311656
print("My Mobile number is" , Mobile_Number)
# Out:
# My Mobile number is 919639311656

# %% [markdown]
# 7. Store a boolean value (True/False).

# %%
True_False = 1
print(bool(True_False))
# Out:
# True

# %% [markdown]
# 8. Comparison Operators

# %%
a = 10
b= 7
print(a>b)
print(a<b)
print(a == b)
print(a != b)
# Out:
# True
# False
# False
# True

# %% [markdown]
# 9. Check Even or Odd

# %%
a = 9
b = 8
print(a % 2 == 0)
print(b % 2 == 0)
# Out:
# False
# True

# %% [markdown]
# 10. Boolean with AND Boolean with OR

# %%
a = 5
b = 7
print(a>b and b>a)
print(a>b or b>a)
# Out:
# False
# True

# %% [markdown]
# 11. Create variables for marks in 3 subjects.

# %%
# Vikas has marks in Physics, Chemistry and Maths
Physics = 80
Chemistry = 70
Maths = 60

print("Marks in Physics" , Physics)
print("Marks in Chemistry" , Chemistry)
print("Marks in Maths" , Maths)
# Out:
# Marks in Physics 80
# Marks in Chemistry 70
# Marks in Maths 60

# %% [markdown]
# 12. Calculate age using variables.

# %%
Current_Year = 2026
Birth_Year = 1986

print("Vikas age is" , Current_Year - Birth_Year)
# Out:
# Vikas age is 40

# %% [markdown]
# 13. few examples for input Function

# %%
age = int(input("Enter your age:"))

print("Next year your age will be:", age + 1)
# Out:
# Enter your age:45
# Next year your age will be: 46
