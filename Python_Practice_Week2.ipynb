# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasmalhotra9/FirstGitProject/blob/Python_Practice/Python_Practice_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create a Simple List

# %%
Subjects = ["BITS" , "Python"]
print(Subjects)
# Out:
# ['BITS', 'Python']

# %% [markdown]
# 2. Access List Items

# %%
Subjects = ["BITS" ,  "Python" , "5G"]
print(Subjects[-1])
print(Subjects[1])
print(Subjects[2])
# Out:
# 5G
# Python
# 5G

# %% [markdown]
# 3. Change List Item.

# %%
Fruits = ["Apple" , "Mango" , "Banana"]
Fruits[2] = "Grapes"
print(Fruits)
# Out:
# ['Apple', 'Mango', 'Grapes']

# %% [markdown]
# 4. Add Item to List.

# %%
Colors = ["Red" , "Green" , "Blue"]
Colors.append("Yellow")
print(Colors)
# Out:
# ['Red', 'Green', 'Blue', 'Yellow']

# %% [markdown]
# 5. Remove Item from List.

# %%
Colors = ["Red" , "Green" , "Blue"]
Colors.remove("Green")
print(Colors)
# Out:
# ['Red', 'Blue']

# %% [markdown]
# 6. Length of List

# %%
Items = ["A", "B" ,"C"]
print(len(Items))
# Out:
# 3

# %% [markdown]
# 7. Loop Through a List

# %%
Fruits = ["Apple" , "Mango" , "Banana"]
for x in Fruits:
  print(x)
# Out:
# Apple
# Mango
# Banana

# %% [markdown]
# 8. Sort a List

# %%
Numbers = [1 , 2 , 9 , 7]
Numbers.sort()
print(Numbers)
# Out:
# [1, 2, 7, 9]

# %% [markdown]
# 9. List of Mixed Data Types

# %%
data = ["Vikas", 9, 4.5, True]
print(data)
# Out:
# ['Vikas', 9, 4.5, True]

# %% [markdown]
# 10. Login System with Multiple Conditions.

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "password":
    print("Login successful!")
else:
    print("Invalid username or password.")
# Out:
# Enter username: Admin
# Enter password: password
# Invalid username or password.

# %% [markdown]
# 11. Student Grade System.

# %%
marks = input("Enter your marks: ")
marks = int(marks)

if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
elif marks >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter your marks: 40
# Grade: F

# %% [markdown]
# 12. ATM Withdrawal System

# %%
balance = 5000

withdraw = int(input("Enter withdrawal amount: "))

if withdraw <= balance:
   balance -= withdraw
   print("Withdrawal Successful")
else:
   print("Insufficient Balance")
# Out:
# Enter withdrawal amount: 800
# Withdrawal Successful
